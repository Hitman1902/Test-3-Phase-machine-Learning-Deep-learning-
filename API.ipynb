# %% [markdown]
# Geocoding Api

# %%
import requests,json
api_keys="e795c6f669232486ce704a9656559915"
city=input('enter the cityyy namee')
request_url="http://api.openweathermap.org/geo/1.0/direct?q="+city+"&appid="+api_keys
response=requests.get(request_url)
coordinates=response.json()
print(coordinates)
lat=coordinates[0]['lat']
long=coordinates[0]['lon']
# Out:
# enter the cityyy nameeDelhi
# [{'name': 'Delhi', 'local_names': {'es': 'Delhi', 'ms': 'Delhi', 'pt': 'Deli', 'zh': '德里', 'th': 'เดลี', 'hi': 'दिल्ली', 'ja': 'デリー', 'te': 'ఢిల్లీ', 'ne': 'दिल्ली', 'lv': 'Deli', 'en': 'Delhi', 'fr': 'Delhi', 'ml': 'ഡെൽഹി', 'de': 'Delhi', 'oc': 'Delhi', 'uk': 'Делі', 'ru': 'Дели', 'ku': 'Delhî', 'bn': 'দিল্লি', 'ur': 'دہلی', 'he': 'דלהי', 'ar': 'دلهي', 'ta': 'தில்லி', 'cs': 'Dillí', 'eo': 'Delhio', 'my': 'ဒေလီမြို့', 'ko': '델리', 'el': 'Δελχί', 'kn': 'ದೆಹಲಿ', 'pa': 'ਦਿੱਲੀ', 'fa': 'دهلی'}, 'lat': 28.6517178, 'lon': 77.2219388, 'country': 'IN', 'state': 'Delhi'}]

# %%
# Current weather data

# %%
# import requests,json
request_url="https://api.openweathermap.org/data/2.5/weather?lat="+str(lat)+"&lon="+str(long)+"&appid="+api_keys
response=requests.get(request_url)
weather=response.json()
print(weather)
# Out:
# {'coord': {'lon': 72.5797, 'lat': 23.0216}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 304.19, 'feels_like': 309.68, 'temp_min': 304.19, 'temp_max': 304.19, 'pressure': 1000, 'humidity': 66, 'sea_level': 1000, 'grnd_level': 995}, 'visibility': 5000, 'wind': {'speed': 3.09, 'deg': 220}, 'clouds': {'all': 40}, 'dt': 1720767185, 'sys': {'type': 1, 'id': 9049, 'country': 'IN', 'sunrise': 1720744305, 'sunset': 1720792709}, 'timezone': 19800, 'id': 1279233, 'name': 'Ahmedabad', 'cod': 200}

# %%
desc=weather['weather'][0]['description']
# Out:
# haze

# %%
temp=weather['main']['temp']
print(temp)
# Out:
# 304.19

# %%
pressure=weather['main']['pressure']
print(pressure)
# Out:
# 1000

# %%
humidity=weather['main']['humidity']
print(humidity)
# Out:
# 66

# %%
wind_speed=weather['wind']['speed']
print(wind_speed)
# Out:
# 3.09

# %%
visibility=weather['visibility']
print(visibility)
# Out:
# 5000

# %%
request_url="http://api.openweathermap.org/data/2.5/air_pollution?lat="+str(lat)+"&lon="+str(long)+"&appid="+api_keys
response=requests.get(request_url)
aqi=response.json()
print(aqi)
# Out:
# {'coord': {'lon': 77.2219, 'lat': 28.6517}, 'list': [{'main': {'aqi': 3}, 'components': {'co': 447.27, 'no': 0.69, 'no2': 6, 'o3': 134.47, 'so2': 12.04, 'pm2_5': 34.16, 'pm10': 51.3, 'nh3': 7.03}, 'dt': 1720768149}]}

# %%
aqi_index=aqi['list'][0]['main']['aqi']
print(aqi_index)
# Out:
# 3

# %%
quantity={1:'Good',2:'fair',3:'Moderate',4:'Poor',5:'very Good'}
# Method 1:
# if aqi_index in quantity.keys():
#     print(quantity[aqi_index])
# Method 2:
# for i,j in quantity.items():
#     if i==aqi_index:
#         print(j)
# Method 3:
# k=quantity[aqi_index]
# print(k)
# Out:
# Moderate

# %%
import requests,json
api_keys="e795c6f669232486ce704a9656559915"
city=input('enter the cityyy namee')
request_url="http://api.openweathermap.org/geo/1.0/direct?q="+city+"&appid="+api_keys
response=requests.get(request_url)
coordinates=response.json()
# print(coordinates)
lat=coordinates[0]['lat']
long=coordinates[0]['lon']
request_url="http://api.openweathermap.org/data/2.5/forecast?lat="+str(lat)+"&lon="+str(long)+"&appid="+api_keys
response=requests.get(request_url)
days_5=response.json()
print(json.dumps(days_5,indent=5))
# Out:
# enter the cityyy nameeAhmedabad
# {
#      "cod": "200",
#      "message": 0,
#      "cnt": 40,
#      "list": [
#           {
#                "dt": 1721109600,
#                "main": {
#                     "temp": 302.56,
#                     "feels_like": 308.58,
#                     "temp_min": 302.56,
#                     "temp_max": 307.31,
#                     "pressure": 1000,
#                     "sea_level": 1000,
#                     "grnd_level": 994,
#                     "humidity": 78,
#                     "temp_kf": -4.75
#                },
#                "weather": [
#                     {
#                          "id": 804,
#                          "main": "Clouds",
#                          "description": "overcast clouds",
#                          "icon": "04d"
#                     }
#                ],
#                "clouds": {
#                     "all": 99
#                },
#                "wind": {
# ...

# %%
n=[]
p=[]
q=[]
r=[]
s=[]
for i in days_5['list']:
    n.append(i['main']['temp'])
    p.append(i['main']['pressure'])
    q.append(i['main']['humidity'])
    r.append(i['weather'][0]['description'])
    s.append(i['dt_txt'])
print(r)
# d={'date_time':s,'temp':n,'pressure':p,'humidity':q,'description':r}
# import pandas as pd
# data=pd.DataFrame(d)
# data
# Out:
# ['overcast clouds', 'light rain', 'light rain', 'light rain', 'very heavy rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'moderate rain', 'light rain', 'light rain', 'broken clouds', 'overcast clouds', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'light rain', 'light rain', 'light rain', 'moderate rain', 'moderate rain', 'moderate rain', 'light rain', 'light rain', 'light rain', 'light rain', 'light rain', 'light rain', 'light rain', 'light rain', 'overcast clouds', 'overcast clouds', 'broken clouds']

# %%
import requests,json
api_keys="e795c6f669232486ce704a9656559915"
city=input('enter the cityyy namee')
request_url="http://api.openweathermap.org/geo/1.0/direct?q="+city+"&appid="+api_keys
response=requests.get(request_url)
coordinates=response.json()
# print(coordinates)
lat=coordinates[0]['lat']
long=coordinates[0]['lon']
request_url="http://api.openweathermap.org/data/2.5/forecast?lat="+str(lat)+"&lon="+str(long)+"&appid="+api_keys
response=requests.get(request_url)
days_5=response.json()
print(json.dumps(days_5,indent=5))
# Out:
# enter the cityyy nameeDelhi
# {
#      "cod": "200",
#      "message": 0,
#      "cnt": 40,
#      "list": [
#           {
#                "dt": 1721109600,
#                "main": {
#                     "temp": 307.15,
#                     "feels_like": 314.15,
#                     "temp_min": 307.15,
#                     "temp_max": 311.04,
#                     "pressure": 1001,
#                     "sea_level": 1001,
#                     "grnd_level": 975,
#                     "humidity": 69,
#                     "temp_kf": -3.89
#                },
#                "weather": [
#                     {
#                          "id": 500,
#                          "main": "Rain",
#                          "description": "light rain",
#                          "icon": "10d"
#                     }
#                ],
#                "clouds": {
#                     "all": 40
#                },
#                "wind": {
#                     "speed": 3.45,
# ...

# %%
delhi_temp=[]
for i in days_5['list']:
    delhi_temp.append(i['main']['temp'])
print(delhi_temp)
# Out:
# [307.15, 309.22, 312.45, 310.26, 309.19, 307.67, 306.71, 307.92, 310.91, 312.29, 310.64, 309.46, 308.16, 307.09, 306.64, 305.72, 307.56, 310.01, 309.19, 305.6, 304.05, 304.38, 303.77, 305.65, 309.72, 311.46, 312.55, 310.01, 307.99, 307.12, 306.09, 308.26, 309.97, 313.65, 312.08, 309.15, 308.71, 307.95, 307.21, 307.35]

# %%
import pandas as pd
Data={'date_time':s,'Ahm_temp':n,'delhi_temp':delhi_temp}
df=pd.DataFrame(Data)
df
# Out:
#               date_time  Ahm_temp  delhi_temp
# 0   2024-07-16 06:00:00    302.56      307.15
# 1   2024-07-16 09:00:00    307.30      309.22
# 2   2024-07-16 12:00:00    309.25      312.45
# 3   2024-07-16 15:00:00    303.94      310.26
# 4   2024-07-16 18:00:00    300.65      309.19
# 5   2024-07-16 21:00:00    301.67      307.67
# 6   2024-07-17 00:00:00    301.31      306.71
# 7   2024-07-17 03:00:00    300.76      307.92
# 8   2024-07-17 06:00:00    304.71      310.91
# 9   2024-07-17 09:00:00    307.16      312.29
# 10  2024-07-17 12:00:00    306.28      310.64
# 11  2024-07-17 15:00:00    303.65      309.46
# 12  2024-07-17 18:00:00    302.60      308.16
# 13  2024-07-17 21:00:00    302.26      307.09
# 14  2024-07-18 00:00:00    302.15      306.64
# 15  2024-07-18 03:00:00    303.39      305.72
# 16  2024-07-18 06:00:00    305.27      307.56
# 17  2024-07-18 09:00:00    307.14      310.01
# 18  2024-07-18 12:00:00    305.78      309.19
# ...

# %%
df['Difference']=df['Ahm_temp']-df['delhi_temp']

# %%
df
# Out:
#               date_time  Ahm_temp  delhi_temp  Difference
# 0   2024-07-16 06:00:00    302.56      307.15       -4.59
# 1   2024-07-16 09:00:00    307.30      309.22       -1.92
# 2   2024-07-16 12:00:00    309.25      312.45       -3.20
# 3   2024-07-16 15:00:00    303.94      310.26       -6.32
# 4   2024-07-16 18:00:00    300.65      309.19       -8.54
# 5   2024-07-16 21:00:00    301.67      307.67       -6.00
# 6   2024-07-17 00:00:00    301.31      306.71       -5.40
# 7   2024-07-17 03:00:00    300.76      307.92       -7.16
# 8   2024-07-17 06:00:00    304.71      310.91       -6.20
# 9   2024-07-17 09:00:00    307.16      312.29       -5.13
# 10  2024-07-17 12:00:00    306.28      310.64       -4.36
# 11  2024-07-17 15:00:00    303.65      309.46       -5.81
# 12  2024-07-17 18:00:00    302.60      308.16       -5.56
# 13  2024-07-17 21:00:00    302.26      307.09       -4.83
# 14  2024-07-18 00:00:00    302.15      306.64       -4.49
# ...

# %% [markdown]
# # Web Scrapping [Beautiful soup]

# %%
import requests
from bs4 import BeautifulSoup
website='https://subslikescript.com/movie/Titanic-120338'
result=requests.get(website)
content=result.text
soup=BeautifulSoup(content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Titanic (1997) Movie Script  | Subs like Script
#   </title>
#   <meta "="" content="Read " created="" from="" movie="" name="description" script,="" srt="" subtitles="" titanic"=""/>
#   <meta content="transcript, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
title=soup.find('h1').text
print(title)
# Out:
# Titanic (1997) - full transcript

# %%
box=soup.find('article',class_='main-article')
box
# Out:
# <article class="main-article">
# <h1>Titanic (1997) - full transcript</h1>
# <p class="plot">A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.</p>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9736463211397065"></script>
# <!-- content_before_content_square_adaptive -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9736463211397065" data-ad-format="auto" data-ad-slot="9732296380" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#     (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <div class="full-script">
#         foodval.com - stop by if you're interested in the nutritional composition of food <br/> --- <br/>
# ...

# %%
box_title=box.find('h1')
box_title
script=box.find('div',class_='full-script').text
(script).encode('utf-8')
# Out:
# b'\n        foodval.com - stop by if you\'re interested in the nutritional composition of food  --- \n        13 meters. You should see it.Okay, take her up and over the bow rail.Mir 2, we\'re going over the bow.Stay with us.Okay, quiet. We\'re rolling.Seeing her coming out of thedarkness like a ghost ship...still gets me every time.To see the sad ruin of thegreat ship sitting here...where she landed at2:30 in the morningof April 15, 1912...after her long fall...from the world above.\n\n\n\nYou are so full of shit, boss.Dive 6. Here we are againon the deck of Titanic.21/2 miles down. 3,821 meters.The pressure outside is31/2 tons per square inch.These windows are9 inches thick.If they go, it\'s sayonarain two microseconds.All right, enough of that bullshit.Just put her down on the roof ofthe officers\' quarters like yesterday.Mir 2, we\'re landing right over theGrand Staircase. You guys set to launch?Yeah, Brock. Launching Dunkin now.Go, Charlie.- All right, tether out.- Tether out.Ok
# ...

# %%
file=open(box_title.text,'w',encoding='utf-8')
file.write(script)
# Out:
# 60517

# %%
listed=soup.find('ul',class_='scripts-list')
print(listed.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-8d397d3e8f09> in <module>
#       1 listed=soup.find('ul',class_='scripts-list')
# ----> 2 print(listed.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests
from bs4 import BeautifulSoup
website="https://subslikescript.com/movies"
result=requests.get(website)
content=result.text
soup=BeautifulSoup(content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    All English transcripts for movies  | Subs like Script
#   </title>
#   <meta content="List of movie scripts " name="description"/>
#   <meta content="transcript, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link as="style" href="https://subslikescript.com/build/assets/app-55ca003e.css" rel="preload">
# ...

# %%
listed=soup.find('ul',class_='scripts-list')
print(listed.text)
# Out:
#         All About Steve (2009)
#
#
#
#
#         Hudson (2019)
#
#
#
#
#         In Praise of Love (2001)
#
#
#
#
#         Grand Knighthawk: Infiltrating the KKK (2023)
#
#
#
#
#
#
#
#
#         7 Days in Havana (2011)
#
#
#
#
#         Love You Ram (2023)
#
#
#
#
#         Clue: A Love Thriller (2021)
#
#
#
#
#         Dave Hughes: Ridiculous (2023)
#
#
#
#
#         Snoopy Presents: One-of-a-Kind Marcie (2023)
#
#
#
#
#         The Lady of Heaven (2021)
#
#
#
#
#         Legacy of Lies (2020)
#
#
#
#
#         Elisabeth (2022)
#
#
#
#
#         Night of the Killer Bears (2022)
#
#
#
#
#         Chrissy Judy (2022)
#
#
#
#
#         Strive (2019)
#
#
#
#
#         Circle Line (2023)
#
#
#
#
#         Juara (2016)
#
#
#
#
#         Wait with Me (2023)
#
#
#
#
#         Falcon Lake (2022)
#
#
#
#
#         Giuseppe w Warszawie (1964)
#
#
#
#
#         Not Broken (2021)
#
#
#
#
#
#
#
#
#         To A Moral Certainty (2022)
#
#
#
#
#         Them (2021)
#
#
#
#
# ...

# %%
# x=listed.find_all('li')
# for i in range(0,30):
#     file=open(x[i].find('a',href=True).text,'w')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-50-f7790f02f186> in <module>
#       1 x=listed.find_all('li')
#       2 for i in range(0,30):
# ----> 3     file=open(x[i].find('a',href=True).text,'w')
#
# OSError: [Errno 22] Invalid argument: '\n        All About Steve (2009)\n    '

# %%
p=listed.find_all('a',href=True)
p
links=[]
for i in p:
    links.append(i['href'])
print(links)
# Out:
# [<a href="/movie/All_About_Steve-881891" title="Read transcript of Movie 'All About Steve'">
#          All About Steve (2009)
#      </a>,
#  <a href="/movie/Hudson-7391126" title="Read transcript of Movie 'Hudson'">
#          Hudson (2019)
#      </a>,
#  <a href="/movie/In_Praise_of_Love-181912" title="Read transcript of Movie 'In Praise of Love'">
#          In Praise of Love (2001)
#      </a>,
#  <a href="/movie/Grand_Knighthawk_Infiltrating_the_KKK-27625793" title="Read transcript of Movie 'Grand Knighthawk: Infiltrating the KKK'">
#          Grand Knighthawk: Infiltrating the KKK (2023)
#      </a>,
#  <a href="/movie/7_Days_in_Havana-1797348" title="Read transcript of Movie '7 Days in Havana'">
#          7 Days in Havana (2011)
#      </a>,
#  <a href="/movie/Love_You_Ram-27655393" title="Read transcript of Movie 'Love You Ram'">
#          Love You Ram (2023)
#      </a>,
# ...

# %%
links=[]
for i in p:
    links.append(i['href'])
print(links)
# Out:
# ['/movie/All_About_Steve-881891', '/movie/Hudson-7391126', '/movie/In_Praise_of_Love-181912', '/movie/Grand_Knighthawk_Infiltrating_the_KKK-27625793', '/movie/7_Days_in_Havana-1797348', '/movie/Love_You_Ram-27655393', '/movie/Clue_A_Love_Thriller-15211098', '/movie/Dave_Hughes_Ridiculous-26343416', '/movie/Snoopy_Presents_One-of-a-Kind_Marcie-27865284', '/movie/The_Lady_of_Heaven-13097336', '/movie/Legacy_of_Lies-6834916', '/movie/Elisabeth-21201264', '/movie/Night_of_the_Killer_Bears-21924062', '/movie/Chrissy_Judy-20117432', '/movie/Strive-3505898', '/movie/Circle_Line-6562232', '/movie/Juara-10329546', '/movie/Wait_with_Me-23147592', '/movie/Falcon_Lake-11448830', '/movie/Giuseppe_w_Warszawie-58143', '/movie/Not_Broken-15007416', '/movie/To_A_Moral_Certainty-20357978', '/movie/Them-12805730', '/movie/Song_of_Love-39850', '/movie/Ningen_kyki_Ai_to_ikari_no_ringu-304476', '/movie/Lewis_Capaldi_How_Im_Feeling_Now-27078772', '/movie/The_Fortune_Code-97394', '/movie/Haunting_Fear-99742
# ...

# %%
root='https://subslikescript.com'
for link in links:
    website=root+link
    result=results.get(website)
    content=result.text
    soup=BeautifulSoup(content,'html.parser')
    box=soup.find('article',class_='main-article')
    title=box.find('h1').text
    try:
        transcript=box.find('div',class_='full-script').text.strip()
        file=open(f'{title}.txt','w',encoding='utf-8')
        file.write(transcript)
    except Exception as e:
        continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8aeeaef8246> in <module>
#       1 root='https://subslikescript.com'
# ----> 2 for link in links:
#       3     website=root+link
#       4     result=results.get(website)
#       5     content=result.text
#
# NameError: name 'links' is not defined

# %%
import requests
from bs4 import BeautifulSoup
website='https://www.politifact.com/factchecks/?_gl=1*1ggqsqj*_ga*MjQ0NTQ5Njc3LjE3MjEzNzIzMTA.*_ga_EDXB0TJGGY*MTcyMTM3MjMwOS4xLjEuMTcyMTM3MjMzNy4wLjAuMA..'
result=requests.get(website)
content=result.text
soup=BeautifulSoup(content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Fact-checks | PolitiFact
#   </title>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="description">
#    <meta content="all" name="robots">
#     <meta content="PolitiFact" name="publisher"/>
#     <meta content="PolitiFact" name="twitter:username">
#      <meta content="summary" name="twitter:card">
#       <meta content="PolitiFact" name="twitter:site"/>
#       <meta content="" name="twitter:url">
#        <meta content="" name="twitter:title"/>
#        <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="twitter:description"/>
# ...

# %%
listed=soup.find_all('li',class_='o-listicle__item')
print(listed)
# date=[]
# date=listed.find_all('footer',class_='m-statement__footer')
# print
# Out:
# [<li class="o-listicle__item">
# <article class="m-statement m-statement--is-medium m-statement--mostly-true">
# <div class="m-statement__author">
# <div class="m-statement__avatar">
# <div class="m-statement__image">
# <div class="c-image" style="padding-top: 119.27710843373494%;">
# <img class="c-image__thumb" height="99" src="https://static.politifact.com/CACHE/images/politifact/mugs/Trump_Jr_muh/333571463a9b62bb0d7322889726ec15.jpg" width="83"/>
# <picture>
# <img class="c-image__original" height="178" src="https://static.politifact.com/CACHE/images/politifact/mugs/Trump_Jr_muh/319a9a909a7552eec24126c4ef4646c5.jpg" width="166"/>
# </picture>
# </div>
# </div>
# </div>
# <div class="m-statement__meta">
# <a class="m-statement__name" href="/personalities/donald-trump-jr/" title="Donald Trump Jr.">
# Donald Trump Jr.
# </a>
# <div class="m-statement__desc">
# stated on July 17, 2024 in Speech:
# </div>
# </div>
# </div>
# <div class="m-statement__content">
# ...

# %%
date1=soup.find_all('footer',class_='m-statement__footer')
for i in data1:
    print(i.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-11d08073346a> in <module>
#       1 date1=soup.find_all('footer',class_='m-statement__footer')
# ----> 2 for i in data1:
#       3     print(i.text)
#
# NameError: name 'data1' is not defined

# %%
name_data=[]
for i in listed:
    name=i.find('a',class_='m-statement__name').text.strip()
    name_data.append(name)
print(name_data)
# Out:
# ['Donald Trump Jr.', 'Kamala Harris', 'Facebook posts', 'Jon Stewart', 'Kari Lake', 'Threads posts', 'X posts', 'Threads posts', 'Instagram posts', 'Social Media', 'Instagram posts', 'Threads posts', 'Instagram posts', 'Threads posts', 'X posts', 'Threads posts', 'Facebook posts', 'Threads posts', 'X posts', 'Joe Biden', 'Social Media', 'Social Media', 'Social Media', 'Instagram posts', 'Facebook posts', 'Threads posts', 'Joe Biden', 'Threads posts', 'Social Media', 'D.L. Hughley']

# %%
statement=[]
for i in listed:
    statement_data=i.find('div',class_='m-statement__quote').text.strip()
    statement.append(statement_data)
print(statement)
# Out:
# ['After being shot at a Milwaukee rally in 1912, former President Teddy Roosevelt “finished his speech and he kept fighting.”', '"Unlike Mike Pence, (J.D.) Vance said he would have carried out Trump\'s plan to overturn the 2020 election."', 'A photo shows proof of a bullet hole in Trump’s jacket.', "Milwaukee's Marcus Performing Arts Center – where 'The Daily Show' had been scheduled – “was originally located in the ‘soft perimeter,’ they called it, security-wise” but “was shifted, understandably so, to the ‘hard perimeter.’”", '“Just last week, Ruben Gallego voted to let the millions of people who poured into our country illegally cast a ballot in this upcoming election.”', 'The Secret Service staged the July 13 shooting at Trump rally.', 'Video shows Donald Trump sleeping at the Republican National Convention’s first night.', 'Photo shows that two days after former President Donald Trump’s attempted assassination, the top part of his ear “grew back.”', 'The shooter who attempted to
# ...

# %%
date_data=[]
for i in listed:
    date=i.find('footer').text.split('•')
    date_data.append(date[1].strip())
print(date_data)
# Out:
# ['July 18, 2024', 'July 18, 2024', 'July 17, 2024', 'July 17, 2024', 'July 17, 2024', 'July 17, 2024', 'July 17, 2024', 'July 16, 2024', 'July 16, 2024', 'July 16, 2024', 'July 16, 2024', 'July 16, 2024', 'July 15, 2024', 'July 15, 2024', 'July 15, 2024', 'July 15, 2024', 'July 15, 2024', 'July 15, 2024', 'July 15, 2024', 'July 15, 2024', 'July 15, 2024', 'July 14, 2024', 'July 14, 2024', 'July 14, 2024', 'July 14, 2024', 'July 14, 2024', 'July 13, 2024', 'July 12, 2024', 'July 12, 2024', 'July 12, 2024']

# %%
import pandas as pd
dict={"date":date_data,"statement":statement,"name":name_data}
df=pd.DataFrame(dict)
df
# Out:
#              date                                          statement  \
# 0   July 18, 2024  After being shot at a Milwaukee rally in 1912,...
# 1   July 18, 2024  "Unlike Mike Pence, (J.D.) Vance said he would...
# 2   July 17, 2024  A photo shows proof of a bullet hole in Trump’...
# 3   July 17, 2024  Milwaukee's Marcus Performing Arts Center – wh...
# 4   July 17, 2024  “Just last week, Ruben Gallego voted to let th...
# 5   July 17, 2024  The Secret Service staged the July 13 shooting...
# 6   July 17, 2024  Video shows Donald Trump sleeping at the Repub...
# 7   July 16, 2024  Photo shows that two days after former Preside...
# 8   July 16, 2024  The shooter who attempted to assassinate Donal...
# 9   July 16, 2024  Photos show former President Donald Trump golf...
# 10  July 16, 2024                     Switzerland banned mammograms.
# 11  July 16, 2024  Trump campaign rally gunman Thomas Matthew Cro...
# 12  July 15, 2024  A Secret Service agent named Jonathan Willis s...
# ...

# %% [markdown]
# # STATIC HTML FILE

# %%
import requests
from bs4 import BeautifulSoup
source=open('movie.html')

# %%
soup=BeautifulSoup(source,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Subs like Script - read transcript of any movie or tv show  | Subs like Script
#   </title>
#   <meta content="Transcripts of media are based on its subtitles. Huge database of movies' and series' english scripts " name="description"/>
#   <meta content="transcript, transcription, subtitles, subs, scripts, srt, screenplay, tv show, movies, series, episode, season, film, cartoon, comics, television, read online, dialogues, springfieldspringfield, springfield " name="keywords"/>
# ...

# %%
tvshows=soup.find_all('li')
print(tvshows)
# Out:
# [<li>Blind Detective</li>, <li>Killer Workout</li>, <li>Budapest Noir</li>, <li>Firefly</li>, <li>Warriors of the Rainbow: Seediq Bale II</li>, <li>Sex Appeal</li>, <li>Lonesome</li>, <li>Corri uomo corri</li>, <li>Faraway</li>, <li>The Treasure of Swamp Castle</li>, <li>Australian Survivor - season 4, episode 18 - Episode #4.18</li>, <li>Australian Survivor - season 4, episode 17 - Episode #4.17</li>, <li>Australian Survivor - season 4, episode 16 - Episode #4.16</li>, <li>Australian Survivor - season 4, episode 15 - Episode #4.15</li>, <li>Australian Survivor - season 4, episode 10 - Episode #4.10</li>, <li>Australian Survivor - season 4, episode 9 - Episode #4.9</li>, <li>Australian Survivor - season 4, episode 8 - Episode #4.8</li>, <li>Australian Survivor - season 4, episode 7 - Episode #4.7</li>, <li>Australian Survivor - season 4, episode 6 - Episode #4.6</li>, <li>Australian Survivor - season 4, episode 5 - Episode #4.5</li>, <li>BROS. Last Call - 10</li>, <li>Rubaru Roshni -
# ...

# %%
for i in range(0,10):
    print(tvshows[i].text)
# Out:
# Blind Detective
# Killer Workout
# Budapest Noir
# Firefly
# Warriors of the Rainbow: Seediq Bale II
# Sex Appeal
# Lonesome
# Corri uomo corri
# Faraway
# The Treasure of Swamp Castle

# %% [markdown]
# # Qb 341

# %%
html_doc = """
<html> <head>
<meta http-equiv="Content-Type" content="text/html;
charset=iso-8859-1">
<title>An example of HTML page</title> </head>
<body>
<h2>This is an example HTML page</h2>
<p>
Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nunc at nisi velit, aliquet iaculis est. Curabitur porttitor nisi vel lacus euismod egestas. 
In hac habitasse platea dictumst. In sagittis magna eu odio interdum mollis. Phasellus sagittis pulvinar facilisis. Donec vel odio volutpat tortor 
volutpat commodo. Donec vehicula vulputate sem, vel iaculis urna molestie eget. Sed pellentesque adipiscing tortor, at condimentum elit 
elementum sed. Mauris dignissim elementum nunc, non elementum felis condimentum eu. In in turpis quis erat imperdiet vulputate. 
Pellentesque mauris turpis, dignissim sed iaculis eu, euismod eget ipsum. Vivamus mollis adipiscing viverra. Morbi at sem eget nisl euismod 
porta.</p>
<p><a href="https://www.w3resource.com/html/HTML-tutorials.php">Learn HTML from w3resource.com</a></p>
<p><a href="https://www.w3resource.com/css/CSS-tutorials.php">Learn CSS from 
w3resource.com</a></p> </body> </html> """

# %%
import requests
from bs4 import BeautifulSoup
soup=BeautifulSoup(html_doc,'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta content="text/html;
# charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    An example of HTML page
#   </title>
#  </head>
#  <body>
#   <h2>
#    This is an example HTML page
#   </h2>
#   <p>
#    Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nunc at nisi velit, aliquet iaculis est. Curabitur porttitor nisi vel lacus euismod egestas.
# In hac habitasse platea dictumst. In sagittis magna eu odio interdum mollis. Phasellus sagittis pulvinar facilisis. Donec vel odio volutpat tortor
# volutpat commodo. Donec vehicula vulputate sem, vel iaculis urna molestie eget. Sed pellentesque adipiscing tortor, at condimentum elit
# elementum sed. Mauris dignissim elementum nunc, non elementum felis condimentum eu. In in turpis quis erat imperdiet vulputate.
# Pellentesque mauris turpis, dignissim sed iaculis eu, euismod eget ipsum. Vivamus mollis adipiscing viverra. Morbi at sem eget nisl euismod
# porta.
#   </p>
#   <p>
# ...

# %%
text=soup.find('a').text.strip()
print(text)
# Out:
# Learn HTML from w3resource.com
